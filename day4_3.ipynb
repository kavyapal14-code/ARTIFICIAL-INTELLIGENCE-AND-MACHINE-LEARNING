# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyapal14-code/ARTIFICIAL-INTELLIGENCE-AND-MACHINE-LEARNING/blob/main/day4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 75.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 106.5 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import pickle
import numpy as np

# Load model
with open("iris_model.pkl", "rb") as f:
    model = pickle.load(f)

st.title("Iris Flower Classifier")

st.write("Enter the features below:")
# Out:
# 2026-07-06 06:41:14.359 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:41:15.001
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-07-06 06:41:15.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:41:15.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:41:15.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:41:15.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:41:15.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import numpy as np
st.title("Iris Flower Classifier")

st.write("Enter the features below:")

sepal_length = st.slider("Sepal Length (cm)", 4.0, 8.0, 5.9)
sepal_width  = st.slider("Sepal Width (cm)", 2.0, 4.5, 3.0)
petal_length = st.slider("Petal Length (cm)", 1.0, 7.0, 4.0)
petal_width  = st.slider("Petal Width (cm)", 0.1, 2.5, 1.2)

features = np.array([[sepal_length, sepal_width, petal_length, petal_width]])

if st.button("Predict"):
    prediction = model.predict(features)

    class_names = ["Setosa", "Versicolor", "Virginica"]

    st.success(f"The predicted Iris species is: {class_names[prediction[0]]}")
# Out:
# 2026-07-06 06:59:06.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.492 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-06 06:59:06.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# added 22 packages in 2s
# ⠋
# ⠋3 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# !curl https://loca.lt/mytunnelpassword

# !streamlit run app.py &>/content/log.txt &
# Out:
# 34.29.147.165

# %%
# !npm localtunnel --port 8501
# Out:
# Unknown command: "localtunnel"
#
# To see a list of supported npm commands, run:
#   npm help
